# %%
import pandas as pd
from functools import reduce

# %%
#combine all the Texas hourly usage data in 2015
texas_data1_6 = pd.read_csv('texas-hourly-1-6.csv', na_values=[])
texas_data6_9 = pd.read_csv('texas-hourly-6-9.csv', na_values=[])
texas_data9_10 = pd.read_csv('901-1001_2015all.csv', na_values=[])
texas_data10_11 = pd.read_csv('1001-1101_2015all.csv', na_values=[])
texas_data11_12 = pd.read_csv('1101-1201_2015all.csv', na_values=[])
texas_data12_1 = pd.read_csv('1201-0101_2015all.csv', na_values=[])

# %%
#collect Texas data ID without missing value
dataid = reduce(set.intersection,map(set,[texas_data1_6['localhour'],texas_data6_9['localhour'],texas_data9_10['dataid'],texas_data10_11['dataid'],texas_data11_12['dataid'],texas_data12_1['dataid']]))

# %%
texas_data1_6 = texas_data1_6.rename(columns=lambda x: x.replace('\t', ''))
texas_data1_6 = texas_data1_6.rename(columns={'dataid':'localhour','localhour':'dataid'})
texas_data1_6.replace('\n','')
texas_data1_6 = texas_data1_6[texas_data1_6['dataid'].isin(dataid)]
texas_data1_6.tail()
# Out:
#                       localhour  dataid      air1      air2  air3  \
# 1709065  2015-06-02 00:00:00-05    9938  0.275583  0.000050   0.0
# 1709066  2015-06-02 00:00:00-05    9939  0.137500  0.142467   0.0
# 1709067  2015-06-02 00:00:00-05    9942  0.000000  0.156217   0.0
# 1709068  2015-06-02 00:00:00-05    9971  1.134367  0.000000   0.0
# 1709070  2015-06-02 00:00:00-05    9982  0.311650  0.000000   0.0
#
#          airwindowunit1  aquarium1  bathroom1  bathroom2  bedroom1  \
# 1709065             0.0        0.0    0.00000        0.0   0.00000
# 1709066             0.0        0.0    0.00415        0.0   0.04225
# 1709067             0.0        0.0    0.00000        0.0   0.00000
# 1709068             0.0        0.0    0.00000        0.0   0.00000
# 1709070             0.0        0.0    0.00000        0.0   0.00410
#
#                ...          shed1  sprinkler1       use  utilityroom1  \
# 1709065        ...            0.0         0.0  2.751250       0.00000
# ...

# %%
texas_data6_9 = texas_data6_9.rename(columns=lambda x: x.replace('\t', ''))
texas_data6_9 = texas_data6_9.rename(columns={'dataid':'localhour','localhour':'dataid'})
texas_data6_9.replace('\n','')
texas_data6_9 = texas_data6_9[texas_data6_9['dataid'].isin(dataid)]
texas_data6_9.tail()
# Out:
#                      localhour  dataid      air1      air2  air3  \
# 963023  2015-09-02 00:00:00-05    9938  0.351767  0.000400   0.0
# 963024  2015-09-02 00:00:00-05    9939  0.142283  0.000000   0.0
# 963025  2015-09-02 00:00:00-05    9942  0.203917  0.320383   0.0
# 963026  2015-09-02 00:00:00-05    9971  0.351283  0.000000   0.0
# 963027  2015-09-02 00:00:00-05    9982  0.377283  0.000000   0.0
#
#         airwindowunit1  aquarium1  bathroom1  bathroom2  bedroom1  \
# 963023             0.0        0.0      0.000        0.0     0.000
# 963024             0.0        0.0      0.004        0.0     0.000
# 963025             0.0        0.0      0.000        0.0     0.000
# 963026             0.0        0.0      0.000        0.0     0.000
# 963027             0.0        0.0      0.000        0.0     0.067
#
#               ...          shed1  sprinkler1       use  utilityroom1  \
# 963023        ...            0.0         0.0  2.728933      0.000000
# ...

# %%
texas_data9_10 = texas_data9_10.rename(columns=lambda x: x.replace('\t', ''))
texas_data9_10.replace('\n','')
texas_data9_10 = texas_data9_10[texas_data9_10['dataid'].isin(dataid)]
texas_data9_10.tail()
# Out:
#         dataid               localhour       use      air1  air2  air3  \
# 373314    9982  2015-09-30 20:00:00-05  2.163633  1.080250   NaN   NaN
# 373315    9982  2015-09-30 21:00:00-05  4.110250  0.854350   NaN   NaN
# 373316    9982  2015-09-30 22:00:00-05  1.508667  0.692667   NaN   NaN
# 373317    9982  2015-09-30 23:00:00-05  1.123717  0.533550   NaN   NaN
# 373318    9982  2015-10-01 00:00:00-05  0.811417  0.354483   NaN   NaN
#
#         airwindowunit1  aquarium1  bathroom1  bathroom2     ...       \
# 373314             NaN        NaN        NaN        NaN     ...
# 373315             NaN        NaN        NaN        NaN     ...
# 373316             NaN        NaN        NaN        NaN     ...
# 373317             NaN        NaN        NaN        NaN     ...
# 373318             NaN        NaN        NaN        NaN     ...
#
#         refrigerator1  refrigerator2  security1  shed1  sprinkler1  \
# 373314       0.053617       0.040817        NaN    NaN         NaN
# ...

# %%
texas_data10_11 = texas_data10_11.rename(columns=lambda x: x.replace('\t', ''))
texas_data10_11.replace('\n','')
texas_data10_11 = texas_data10_11[texas_data10_11['dataid'].isin(dataid)]
texas_data10_11.tail()
# Out:
#         dataid               localhour       use     air1  air2  air3  \
# 369889    9982  2015-10-31 20:00:00-05  0.897917  0.15565   NaN   NaN
# 369890    9982  2015-10-31 21:00:00-05  0.856833  0.00000   NaN   NaN
# 369891    9982  2015-10-31 22:00:00-05  1.002700  0.00000   NaN   NaN
# 369892    9982  2015-10-31 23:00:00-05  0.385433  0.00000   NaN   NaN
# 369893    9982  2015-11-01 00:00:00-05  0.400383  0.00000   NaN   NaN
#
#         airwindowunit1  aquarium1  bathroom1  bathroom2     ...       \
# 369889             NaN        NaN        NaN        NaN     ...
# 369890             NaN        NaN        NaN        NaN     ...
# 369891             NaN        NaN        NaN        NaN     ...
# 369892             NaN        NaN        NaN        NaN     ...
# 369893             NaN        NaN        NaN        NaN     ...
#
#         refrigerator1  refrigerator2  security1  shed1  sprinkler1  \
# 369889       0.063367       0.081317        NaN    NaN         NaN
# ...

# %%
texas_data11_12 = texas_data11_12.rename(columns=lambda x: x.replace('\t', ''))
texas_data11_12.replace('\n','')
texas_data11_12 = texas_data11_12[texas_data11_12['dataid'].isin(dataid)]
texas_data11_12.tail()
# Out:
#         dataid               localhour       use  air1  air2  air3  \
# 332023    9982  2015-11-30 20:00:00-06  0.411583   0.0   NaN   NaN
# 332024    9982  2015-11-30 21:00:00-06  0.440583   0.0   NaN   NaN
# 332025    9982  2015-11-30 22:00:00-06  0.265617   0.0   NaN   NaN
# 332026    9982  2015-11-30 23:00:00-06  0.216100   0.0   NaN   NaN
# 332027    9982  2015-12-01 00:00:00-06  0.230417   0.0   NaN   NaN
#
#         airwindowunit1  aquarium1  bathroom1  bathroom2     ...       \
# 332023             NaN        NaN        NaN        NaN     ...
# 332024             NaN        NaN        NaN        NaN     ...
# 332025             NaN        NaN        NaN        NaN     ...
# 332026             NaN        NaN        NaN        NaN     ...
# 332027             NaN        NaN        NaN        NaN     ...
#
#         refrigerator1  refrigerator2  security1  shed1  sprinkler1  \
# 332023        0.05055       0.020950        NaN    NaN         NaN
# ...

# %%
texas_data12_1 = texas_data12_1.rename(columns=lambda x: x.replace('\t', ''))
texas_data12_1.replace('\n','')
texas_data12_1 = texas_data12_1[texas_data12_1['dataid'].isin(dataid)]
texas_data12_1.tail()
# Out:
#         dataid               localhour       use  air1  air2  air3  \
# 333704    9982  2015-12-31 20:00:00-06  0.492500   0.0   NaN   NaN
# 333705    9982  2015-12-31 21:00:00-06  0.550750   0.0   NaN   NaN
# 333706    9982  2015-12-31 22:00:00-06  0.415683   0.0   NaN   NaN
# 333707    9982  2015-12-31 23:00:00-06  0.390033   0.0   NaN   NaN
# 333708    9982  2016-01-01 00:00:00-06  0.450883   0.0   NaN   NaN
#
#         airwindowunit1  aquarium1  bathroom1  bathroom2     ...       \
# 333704             NaN        NaN        NaN        NaN     ...
# 333705             NaN        NaN        NaN        NaN     ...
# 333706             NaN        NaN        NaN        NaN     ...
# 333707             NaN        NaN        NaN        NaN     ...
# 333708             NaN        NaN        NaN        NaN     ...
#
#         refrigerator1  refrigerator2  security1  shed1  sprinkler1  \
# 333704       0.039317       0.012150        NaN    NaN         NaN
# ...

# %%
Texas_data = [texas_data1_6, texas_data6_9, texas_data9_10, texas_data10_11, texas_data11_12, texas_data12_1]
Texas_2015 = pd.concat(Texas_data)

# %%
Texas_2015.fillna(0,inplace= True)

# %%
import gc
del texas_data1_6
del texas_data6_9
del texas_data9_10
del texas_data10_11
del texas_data11_12
del texas_data12_1
gc.collect()
# Out:
# 287

# %%
hourly_data_PSTexas =Texas_2015[['dataid']] #the summarized data from Texas
hourly_data_PSTexas['Localhour'] =Texas_2015[['localhour']]
hourly_data_PSTexas['Total_use'] = Texas_2015['use']
hourly_data_PSTexas['Space_heat'] = Texas_2015['heater1']
hourly_data_PSTexas['Cooling'] = Texas_2015['airwindowunit1'] + Texas_2015['air1'] + Texas_2015['air2'] + Texas_2015['air3']
hourly_data_PSTexas['Water_heat'] = Texas_2015['waterheater1'] + Texas_2015['waterheater2']
hourly_data_PSTexas['Refrigerator'] = Texas_2015['refrigerator1'] + Texas_2015['refrigerator2']
hourly_data_PSTexas['Freezer'] = Texas_2015['freezer1']
hourly_data_PSTexas['Oven'] = Texas_2015['range1'] + Texas_2015['oven1'] + Texas_2015['oven2']
hourly_data_PSTexas['Microwave'] = Texas_2015['microwave1']
hourly_data_PSTexas['Clotheswasher'] = Texas_2015['clotheswasher1']
hourly_data_PSTexas['Clothesdryer'] = Texas_2015['clotheswasher_dryg1']
hourly_data_PSTexas['Dishwasher'] = Texas_2015['dishwasher1']
hourly_data_PSTexas['Furnace'] = Texas_2015['furnace1']
hourly_data_PSTexas['Pool_pump'] = Texas_2015['poolpump1']
hourly_data_PSTexas['Hot_tub_pumb'] =Texas_2015['jacuzzi1'] + Texas_2015['pump1']
hourly_data_PSTexas['Light&fan'] = Texas_2015['bathroom1'] + Texas_2015['bathroom2']+ Texas_2015['bedroom1']+ Texas_2015['bedroom2']+ Texas_2015['bedroom3']+ Texas_2015['bedroom4']+ Texas_2015['bedroom5']+ Texas_2015['diningroom1']+ Texas_2015['diningroom2']+ Texas_2015['garage1']+Texas_2015['garage2']+ Texas_2015['kitchen1']+ Texas_2015['kitchen2']+Texas_2015['lights_plugs1']+ Texas_2015['lights_plugs2']+Texas_2015['lights_plugs3']+ Texas_2015['lights_plugs4']+ Texas_2015['lights_plugs5']+ Texas_2015['lights_plugs6']+ Texas_2015['livingroom1']+ Texas_2015['livingroom2']+ Texas_2015['office1']+ Texas_2015['outsidelights_plugs1']+ Texas_2015['outsidelights_plugs2']+ Texas_2015['poollight1']+ Texas_2015['housefan1']
# Out:
# E:\Ana\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# E:\Ana\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# E:\Ana\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
hourly_data_PSTexas[hourly_data_PSTexas['dataid']==59]
# Out:
#        dataid               Localhour  Total_use  Space_heat   Cooling  \
# 1          59  2015-01-01 00:00:00-06   3.689283         0.0  2.251383
# 475        59  2015-01-01 01:00:00-06   3.863017         0.0  2.290683
# 949        59  2015-01-01 02:00:00-06   3.471817         0.0  2.250267
# 1423       59  2015-01-01 03:00:00-06   3.562250         0.0  2.018917
# 1897       59  2015-01-01 04:00:00-06   3.229150         0.0  2.090683
# 2371       59  2015-01-01 05:00:00-06   3.704500         0.0  2.189567
# 2845       59  2015-01-01 06:00:00-06   3.966783         0.0  2.171450
# 3319       59  2015-01-01 07:00:00-06   5.560983         0.0  1.935950
# 3793       59  2015-01-01 08:00:00-06   5.903100         0.0  1.861033
# 4266       59  2015-01-01 09:00:00-06   4.807283         0.0  1.627933
# 4740       59  2015-01-01 10:00:00-06   5.465733         0.0  1.486583
# 5214       59  2015-01-01 11:00:00-06   6.023133         0.0  1.839433
# ...

# %%
hourly_data_PSTexas.to_pickle('./hourly_data_PSTexas.pickle')

# %%
import pandas as pd
import numpy as np
hourly_data_PSTexas=pd.read_pickle('hourly_data_PSTexas.pickle')

# %%
#remove data with missing value
train={}
for i in dataid:
    if hourly_data_PSTexas[hourly_data_PSTexas['dataid']==i].sort_values(by='Localhour').values[:,2:].shape == (8814, 15):
        train[i]=(hourly_data_PSTexas[hourly_data_PSTexas['dataid']==i].sort_values(by='Localhour').values[:,2:])

# %%
np.save('./PreprocessedData/hourly_data_PSTexas_trainingset',np.array(list(train.values())))

# %%
np.save('./PreprocessedData/hourly_data_PSTexas_HouseholdID',np.array(list(train.keys())))

# %%
hourly_data_PSTexas_trainingset=np.load('./PreprocessedData/hourly_data_PSTexas_trainingset.npy')

# %%
#calculate the daily data in Texas and save
daily_data_PSTexas_data=[]
for j in range(len(train)):
    first = np.sum(hourly_data_PSTexas_trainingset[j,0:24,:],axis=0)
    for i in range(1,365):
        first = np.vstack([first,np.sum(hourly_data_PSTexas_trainingset[j,i*24:(i+1)*24,:],axis=0)])
    daily_data_PSTexas_data.append(first)
daily_data_PSTexas_data=np.array(daily_data_PSTexas_data)
np.save('./PreprocessedData/daily_data_PSTexas_data.npy',daily_data_PSTexas_data)
